# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   41                 1
# 1   50                 0
# 2   37                 1
# 3   49                 1
# 4   52                 1

# %%
plt.scatter(df.age,df.bought_insurance, color='red', marker='+')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.2)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (80, 1) (80,)
# (20, 1) (20,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.7

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1, 1, 1, 0, 1, 1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 1, 1, 1])

# %%
model.predict([[30]])
# Out:
# f:\AI\Machine Learning\Note Book\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict_proba([[20]])
# Out:
# array([[0.414506  , 0.585494  ],
#        [0.60888724, 0.39111276],
#        [0.414506  , 0.585494  ],
#        [0.08535876, 0.91464124],
#        [0.0624218 , 0.9375782 ],
#        [0.52620608, 0.47379392],
#        [0.46998014, 0.53001986],
#        [0.14078229, 0.85921771],
#        [0.60888724, 0.39111276],
#        [0.63534337, 0.36465663],
#        [0.17027731, 0.82972269],
#        [0.36111846, 0.63888154],
#        [0.0624218 , 0.9375782 ],
#        [0.10465645, 0.89534355],
#        [0.52620608, 0.47379392],
#        [0.14078229, 0.85921771],
#        [0.24353894, 0.75646106],
#        [0.12770777, 0.87229223],
#        [0.36111846, 0.63888154],
#        [0.28736223, 0.71263777]])
